# %% [markdown]
# <br>
#
# # <span style="color:deepskyblue"> **Exploratory Data Analysis - Retail (SampleSuperstore.csv)**
#
# ### **BY: [GINO FREUD D. HOBAYAN](https://www.linkedin.com/in/ginofreudhobayan/)**
#
# <br>
#
# ### **Data science and Business Analytics Intern**
# ### **The Sparks Foundation**

# %% [markdown]
# <br>
# <br>
# <br>
#
# ## **What Business problems can I derive by exploring the data?**
#
#
# ### <span style="color:deepskyblue">  **As a business manager, try to find out the weak areas where I can work to make profit.**
#
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# <br>
# <br>
# <br>
#
# ## **Import Libraries and the CSV file**

# %%
import numpy as np 
import pandas as pd


import matplotlib.pyplot as plt
import seaborn as sns



superstore_df = pd.read_csv("SampleSuperstore.csv")

# %% [markdown]
# ### What Business problems can i derive by exploring the data?

# %%
superstore_df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
superstore_df.shape
# Out:
# (9994, 13)

# %%
superstore_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
superstore_df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
#
#
# # <span style="color:deepskyblue"> **Data Preparation and Data Cleaning:**

# %% [markdown]
# <br>
# <br>
#
# ## **1. Checking for null values: No null values found**

# %%
missing_superstore_df = superstore_df.isnull().sum().to_frame().rename(columns={0:"Total No. of Missing Values"})

# Divided the total No. of Missing values by the Total length of the dataframe, then round it to 2 decimal places
missing_superstore_df["% of Missing Values"] = round((missing_superstore_df["Total No. of Missing Values"]/len(superstore_df))*100,2)



missing_superstore_df
# Out:
#               Total No. of Missing Values  % of Missing Values
# Ship Mode                               0                  0.0
# Segment                                 0                  0.0
# Country                                 0                  0.0
# City                                    0                  0.0
# State                                   0                  0.0
# Postal Code                             0                  0.0
# Region                                  0                  0.0
# Category                                0                  0.0
# Sub-Category                            0                  0.0
# Sales                                   0                  0.0
# Quantity                                0                  0.0
# Discount                                0                  0.0
# Profit                                  0                  0.0

# %% [markdown]
# <br>
# <br>
# <br>
#
#
# ## **2. Check for duplicate values:**

# %%
superstore_df.duplicated().any()
# Out:
# True

# %%
superstore_df.duplicated().sum()
# Out:
# 17

# %% [markdown]
# ### 17 Duplicate values found.

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# ## Visualize the Duplicates:

# %%
duplicates_count = superstore_df.duplicated().sum()
non_duplicates_count = len(superstore_df) - duplicates_count



# Create data for the pie chart
labels = ['Duplicates', 'Non-Duplicates']
sizes = [duplicates_count, non_duplicates_count]
colors = ['red', 'green']
explode = (0.1, 0)


# Create the pie chart
plt.pie(sizes, 
        explode=explode, 
        labels=labels, 
        colors=colors, 
        autopct='%1.1f%%', 
        shadow=True, 
        startangle=140)
plt.title('Visualize the Duplicates')



plt.show()
print(f"Number of Duplicates found: {duplicates_count}")
print(f"Number of Non-Duplicates: {non_duplicates_count}")
print(f"Superstore Dataset: {len(superstore_df)}")
# Out:
# Number of Duplicates found: 17
# Number of Non-Duplicates: 9977
# Superstore Dataset: 9994

# %% [markdown]
# - 17 values or 0.2% of the data are Duplicates

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# ## Delete Duplicates:

# %%
superstore_df.drop_duplicates(inplace=True)

print("Duplicates successfully dropped/deleted")
# Out:
# Duplicates successfully dropped/deleted

# %%
superstore_df.duplicated().any()
# Out:
# False

# %%
superstore_df.duplicated().sum()
# Out:
# 0

# %%
superstore_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9977 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9977 non-null   object
#  1   Segment       9977 non-null   object
#  2   Country       9977 non-null   object
#  3   City          9977 non-null   object
#  4   State         9977 non-null   object
#  5   Postal Code   9977 non-null   int64
#  6   Region        9977 non-null   object
#  7   Category      9977 non-null   object
#  8   Sub-Category  9977 non-null   object
#  9   Sales         9977 non-null   float64
#  10  Quantity      9977 non-null   int64
#  11  Discount      9977 non-null   float64
#  12  Profit        9977 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.1+ MB

# %%
superstore_df.shape

# Now we only have 9,977 rows - because we deleted the 17 duplicate rows
# Out:
# (9977, 13)

# %% [markdown]
# # <span style="color:deepskyblue"> **Data Cleaning Finished.**
#
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# # <span style="color:deepskyblue"> **Descriptive Statistics:**

# %% [markdown]
# ## **Numerical Descriptive Statistics**
# ### **(with the Five-number Summary)**
#
# - Count: It shows the number of values that are not missing in each of the column.<br>
# - Mean : It shows the average of the values in each of the column.<br>
# - Std :  It shows standard deviation of the values in each of the column.<br>
# - Min :  It shows the smallest value in each of the column.<br>
# - Max :  It shows the maximum value in each of the column.<br>
# - 25%, 50%, 75%: The valuescorrespond to the data divisions of 25%, 50% and 75% percentiles.<br></div>

# %%
superstore_df.describe()                 # Count, Mean, Standard deviation, and the Five-number summary
# Out:
#         Postal Code         Sales     Quantity     Discount      Profit
# count   9977.000000   9977.000000  9977.000000  9977.000000  9977.00000
# mean   55154.964117    230.148902     3.790719     0.156278    28.69013
# std    32058.266816    623.721409     2.226657     0.206455   234.45784
# min     1040.000000      0.444000     1.000000     0.000000 -6599.97800
# 25%    23223.000000     17.300000     2.000000     0.000000     1.72620
# 50%    55901.000000     54.816000     3.000000     0.200000     8.67100
# 75%    90008.000000    209.970000     5.000000     0.200000    29.37200
# max    99301.000000  22638.480000    14.000000     0.800000  8399.97600

# %% [markdown]
# ### Inferences:
#
# - Minimum Profit = -6,599.98
#
# - Mean Profit = 28.66
#
# - Maximum Profit = 8,399.98
#
# - Profit has an IQR of 27.64
#
# <br>
#
# - Minimum Quantity = 1, Maximum Quantity = 14
#
#
# <br>
# <br>

# %% [markdown]
# ## **Categorical Descriptive Statistics**
#
# - Count: It shows the number of values that are not missing in each of the column.<br>
# - Unique : It shows the number of unique values present in each of the ccolumn.<br>
# - Top : It shows which categorical value is present most in each of the column.<br>
# - Freq : It shows the frequency of the categorical value apperaing most in each of the columns.<br></div>

# %%
superstore_df.describe(include="O")
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9977      9977           9977           9977        9977
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5955      5183           9977            914        1996
#
#        Region         Category Sub-Category
# count    9977             9977         9977
# unique      4                3           17
# top      West  Office Supplies      Binders
# freq     3193             6012         1522

# %% [markdown]
# ### Inferences:
#
# - 3 Unique Categories and 17 Unique sub-categories
#
# - 531 Cities, 49 States, and 4 Regions in the US
#
#
# - Top country, City, State, Region: USA, New York City, California, West
#
#
# - Top Shipping mode: Standard Class
#
#
# - Top Category: Office Supplies
#
#
# - Top Sub-Category: Binders
#
#
# <br>
# <br>

# %% [markdown]
# # <span style="color:deepskyblue"> **Exploratory Data Analysis**
#
# <br><br>
#
# ## <span style="color:deepskyblue"> **PART 1: Numerical data**
#
#
# ## <span style="color:deepskyblue"> **PART 2: Categorical data**
#
#
# ## <span style="color:deepskyblue"> **PART 3: Numerical and Categorical data**

# %% [markdown]
# ## <span style="color:deepskyblue"> **PART 1: Numerical data**

# %%
superstore_df.describe()                 # Count, Mean, Standard deviation, and the Five-number summary
# Out:
#         Postal Code         Sales     Quantity     Discount      Profit
# count   9977.000000   9977.000000  9977.000000  9977.000000  9977.00000
# mean   55154.964117    230.148902     3.790719     0.156278    28.69013
# std    32058.266816    623.721409     2.226657     0.206455   234.45784
# min     1040.000000      0.444000     1.000000     0.000000 -6599.97800
# 25%    23223.000000     17.300000     2.000000     0.000000     1.72620
# 50%    55901.000000     54.816000     3.000000     0.200000     8.67100
# 75%    90008.000000    209.970000     5.000000     0.200000    29.37200
# max    99301.000000  22638.480000    14.000000     0.800000  8399.97600

# %% [markdown]
# ## 1. Pairplot to get a bird's eye view of the numerical data

# %% [markdown]
# ### Removed the "Postal Code" column and did a pair plot of the numerical data

# %%
pairplot_df = superstore_df[['Profit','Discount','Quantity', 'Sales']]




sns.pairplot(pairplot_df)               
plt.show()

# %% [markdown]
# ## Inferences:
#
# - Discount and Profit
#
#
# - Quantity and Profit
#
# <br>
#
#
#
# - Sales and Discount
#
#
# - Sales and Profit
#
# <br><br><br>

# %% [markdown]
# <br>
# <br>
# <br>
#
#
# ## <span style="color:deepskyblue"> **We need get to know more our numerical columns**
#
# <br>
#
# ### <span style="color:deepskyblue"> **Let's visualize these Numerical Descriptive statistics using Histograms and Box Plots**

# %% [markdown]
# <br>
# <br>
#
# 1. **Histograms**:
#    - Create histograms for "Sales," "Quantity," "Discount," and "Profit" to visualize their distributions.
#
#       <span style="color:deepskyblue"> **This will help us understand the data's central tendency and spread.**
#
#
# <br><br>
#
#
# 2. **Box Plots**:
#    - Use box plots for each numerical column <span style="color:deepskyblue"> **to identify outliers and assess the spread of our data.**
#
#       This is especially useful for "Sales," "Quantity," "Discount," and "Profit."
#
# <br>
# <br>
# <br>

# %%
superstore_df.describe()                 # Count, Mean, Standard deviation, and the Five-number summary
# Out:
#         Postal Code         Sales     Quantity     Discount      Profit
# count   9977.000000   9977.000000  9977.000000  9977.000000  9977.00000
# mean   55154.964117    230.148902     3.790719     0.156278    28.69013
# std    32058.266816    623.721409     2.226657     0.206455   234.45784
# min     1040.000000      0.444000     1.000000     0.000000 -6599.97800
# 25%    23223.000000     17.300000     2.000000     0.000000     1.72620
# 50%    55901.000000     54.816000     3.000000     0.200000     8.67100
# 75%    90008.000000    209.970000     5.000000     0.200000    29.37200
# max    99301.000000  22638.480000    14.000000     0.800000  8399.97600

# %% [markdown]
# ## Sales

# %%
# Create a histogram for Sales
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.hist(superstore_df['Sales'], 
         bins=20, 
         color='blue', 
         edgecolor='black')
plt.title('Histogram of Sales')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.grid(True)





# Create a boxplot for Sales
plt.subplot(1, 2, 2)
sns.boxplot(y=superstore_df['Sales'], color='green')
plt.title('Boxplot of Sales')
plt.ylabel('Sales')
plt.grid(True)

plt.tight_layout()
plt.show()

print(superstore_df['Sales'].nlargest(10))
# Out:
# 2697    22638.480
# 6826    17499.950
# 8153    13999.960
# 2623    11199.968
# 4190    10499.970
# 9039     9892.740
# 4098     9449.950
# 4277     9099.930
# 8488     8749.950
# 6425     8399.976
# Name: Sales, dtype: float64

# %% [markdown]
# ## Quantity

# %%
plt.figure(figsize=(10, 5))



# Create a histogram 
plt.subplot(1, 2, 1)
plt.hist(superstore_df['Quantity'], 
         bins=20, 
         color='blue', 
         edgecolor='black')
plt.title('Histogram of Quantity')
plt.xlabel('Quantity')
plt.ylabel('Frequency')
plt.grid(True)




# Create a boxplot
plt.subplot(1, 2, 2)
sns.boxplot(y=superstore_df['Quantity'], color='green')
plt.title('Boxplot of Quantity')
plt.ylabel('Quantity')
plt.grid(True)



plt.tight_layout()
plt.show()

# %% [markdown]
# ## Discount

# %%
plt.figure(figsize=(10, 5))


# Create a histogram 
plt.subplot(1, 2, 1)
plt.hist(superstore_df['Discount'], 
         bins=20, 
         color='blue', 
         edgecolor='black')
plt.title('Histogram of Discount')
plt.xlabel('Discount')
plt.ylabel('Frequency')
plt.grid(True)




# Create a boxplot
plt.subplot(1, 2, 2)
sns.boxplot(y=superstore_df['Discount'], color='green')
plt.title('Boxplot of Discount')
plt.ylabel('Discount')
plt.grid(True)



plt.tight_layout()
plt.show()

# %% [markdown]
# ## Profit

# %%
plt.figure(figsize=(10, 5))




# Create a histogram 
plt.subplot(1, 2, 1)
plt.hist(superstore_df['Profit'], 
         bins=20, 
         color='blue', 
         edgecolor='black')
plt.title('Histogram of Profit')
plt.xlabel('Profit')
plt.ylabel('Frequency')
plt.grid(True)




# Create a boxplot
plt.subplot(1, 2, 2)
sns.boxplot(y=superstore_df['Profit'], color='green')
plt.title('Boxplot of Profit')
plt.ylabel('Profit')
plt.grid(True)



plt.tight_layout()
plt.show()

# %% [markdown]
# # **Correlation**

# %%
correlation_matrix = superstore_df[['Profit', 'Sales', 'Quantity', 'Discount']].corr()

# %%
correlation_matrix.corr()
# Out:
#             Profit     Sales  Quantity  Discount
# Profit    1.000000  0.610905 -0.267389 -0.806796
# Sales     0.610905  1.000000 -0.152961 -0.649812
# Quantity -0.267389 -0.152961  1.000000 -0.323142
# Discount -0.806796 -0.649812 -0.323142  1.000000

# %%
sns.heatmap(correlation_matrix, annot=True)

plt.show()

# %% [markdown]
# ### Inferences:
#
# - <span style="color:deepskyblue"> **0.48 correlation between Sales and Profit (POSITIVE CORRELATION)**
#
#
# - <span style="color:red"> **-0.22 correlation between Discount and Profit (NEGATIVE CORRELATION)**
#
#
# - <span style="color:deepskyblue"> **0.20 correlation between Sales and Quantity (POSITIVE CORRELATION)**

# %% [markdown]
# ## <span style="color:deepskyblue"> **Let's dive deeper into the data**
#
# <br>
# <br>

# %% [markdown]
# ## Discount and Profit - Scatterplot

# %%
sns.scatterplot(data=superstore_df,
                x='Profit',
                y='Discount')
# Out:
# <Axes: xlabel='Profit', ylabel='Discount'>

# %% [markdown]
# ### Inferences:
#
# - <span style="color:deepskyblue"> **It seems there is a negative correlation. The Higher the Discount, the Lower the Profit**
#
#    <span style="color:deepskyblue">  **However, correlation does not imply causation, we have to investigate further**
#
#
# <br>
#
# - The -6,000 and 8,000 are outliers, the Mean is 28 just like what we saw in the Descriptive Statistics
#
#
# - Minimum Profit = -6,599.98
#
# - Mean Profit = 28.66
#
# - Maximum Profit = 8,399.98
#
# - Profit has an IQR of 27.64
#
#
#
# <br><br><br>

# %% [markdown]
# ## Profit and Sales - Scatterplot

# %%
sns.scatterplot(data=superstore_df,
                x='Profit',
                y='Sales')
# Out:
# <Axes: xlabel='Profit', ylabel='Sales'>

# %% [markdown]
# ### Inferences:
#
# - There's one item with more than 20,000 Sales but still generate Negative Profits
#
#
# - It seems that the more Sales we make, the more Profit as well, since they are Positively correlated (0.48)
#
#     However, correlation does not imply causation.

# %% [markdown]
# # <span style="color:deepskyblue"> **Exploratory Data Analysis**

# %% [markdown]
# ## <span style="color:deepskyblue"> **PART 2: Categorical data**

# %% [markdown]
# <br>
# <br>
#
# <br>
# <br>
#
#
# ### <span style="color:deepskyblue"> **Let's use Bar charts to see the top in our categorical columns**
#
# ### <span style="color:deepskyblue"> **Let's use Profit on Boxplots to get to know more about our data**
#
# <br>

# %%
superstore_df.describe(include="O")
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9977      9977           9977           9977        9977
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5955      5183           9977            914        1996
#
#        Region         Category Sub-Category
# count    9977             9977         9977
# unique      4                3           17
# top      West  Office Supplies      Binders
# freq     3193             6012         1522

# %% [markdown]
# # **1. Ship Mode**

# %%
# value_counts() = Similar to COUNT() on SQL

superstore_df['Ship Mode'].value_counts()
# Out:
# Standard Class    5955
# Second Class      1943
# First Class       1537
# Same Day           542
# Name: Ship Mode, dtype: int64

# %%
# Create a figure with three subplots side by side
plt.figure(figsize=(15, 5))


# First subplot: Bar chart for top ship modes
top_ship_modes = superstore_df['Ship Mode'].value_counts().nlargest(30)

plt.subplot(1, 3, 1)
top_ship_modes.plot(kind='bar', color='Green', width=0.5)
plt.title('Top Ship Modes by Count')
plt.xticks(rotation=45)



# Second subplot: Boxplot of Profit by Ship Mode
plt.subplot(1, 3, 2)
sns.boxplot(x='Ship Mode', y='Profit', data=superstore_df, palette='Blues')
plt.title('Boxplot of Profit by Ship Mode')
plt.xlabel('Ship Mode')
plt.ylabel('Profit')
plt.xticks(rotation=45)



# Third subplot: Pie chart for distribution of ship modes
ship_mode_counts = superstore_df['Ship Mode'].value_counts()

plt.subplot(1, 3, 3)
plt.pie(ship_mode_counts,
        labels=ship_mode_counts.index,
        autopct='%1.1f%%',
        startangle=140,
        colors=['lightblue', 'tomato', 'lightgreen', 'Yellow'])
plt.title('Distribution of Ship Modes (COUNT)')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle




plt.tight_layout()
plt.show()
print(ship_mode_counts)
# Out:
# Standard Class    5955
# Second Class      1943
# First Class       1537
# Same Day           542
# Name: Ship Mode, dtype: int64

# %% [markdown]
# ### Inferences:
#
# - We make the MOST and LEAST profit on Standard class Ship Mode.
#
# - It contains the 2 biggest outliers (-6,000 and 8,000)
#
# - Standard class also has 59.7% of the total share

# %% [markdown]
# # **2. Segment**

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Create a figure with three subplots side by side
plt.figure(figsize=(15, 5))


# First subplot: Bar chart for top segments
top_segments = superstore_df['Segment'].value_counts().nlargest(30)

plt.subplot(1, 3, 1)
top_segments.plot(kind='bar', color='purple', width=0.5)
plt.title('Top Segments by Count')
plt.xticks(rotation=45)



# Second subplot: Boxplot of Profit by Segment
plt.subplot(1, 3, 2)
sns.boxplot(x='Segment', y='Profit', data=superstore_df, palette='Blues')
plt.title('Boxplot of Profit by Segment')
plt.xlabel('Profit')
plt.ylabel('Sales')
plt.xticks(rotation=45)



# Third subplot: Pie chart for distribution of segments
segment_counts = superstore_df['Segment'].value_counts()

plt.subplot(1, 3, 3)
plt.pie(segment_counts, 
        labels=segment_counts.index, 
        autopct='%1.1f%%', 
        startangle=140, 
        colors=['lightblue', 'tomato', 'lightgreen'])
plt.title('Distribution of Segments (COUNT)')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle



plt.tight_layout()
plt.show()
print(segment_counts)
# Out:
# Consumer       5183
# Corporate      3015
# Home Office    1779
# Name: Segment, dtype: int64

# %% [markdown]
# ### Inferences
#
# - Consumer Segment has the lowest outlier (-6,000)
#
# - Corporate Segment has the highest outlier (8,000+)
#
# - Consumer has more than half of the share (51.9%)

# %% [markdown]
# #  **3. Region**

# %%
plt.figure(figsize=(15, 5))



# First subplot: Bar chart for top regions
top_regions = superstore_df['Region'].value_counts().nlargest(30)

plt.subplot(1, 3, 1)
top_regions.plot(kind='bar', color='deepskyblue', width=0.5)
plt.title('Top Regions by Count')
plt.xticks(rotation=45)



# Second subplot: Boxplot of Profit by Region
plt.subplot(1, 3, 2)
sns.boxplot(x='Region', y='Profit', data=superstore_df, palette='Blues')
plt.title('Boxplot of Profit by Region')
plt.xlabel('Region')
plt.ylabel('Profit')
plt.xticks(rotation=45)




# Third subplot: Pie chart for distribution of regions
region_counts = superstore_df['Region'].value_counts()

plt.subplot(1, 3, 3)
plt.pie(region_counts,
        labels=region_counts.index,
        autopct='%1.1f%%',
        startangle=140,
        colors=['lightblue', 'tomato', 'lightgreen', 'yellow'])
plt.title('Distribution of Regions (COUNT)')
plt.axis('equal')  



plt.tight_layout()
plt.show()
print(region_counts)
# Out:
# West       3193
# East       2845
# Central    2319
# South      1620
# Name: Region, dtype: int64

# %% [markdown]
# # **4. State**

# %%
top_states = superstore_df['State'].value_counts().nlargest(20)


# Create the Bar Chart
plt.figure(figsize=(12,3))
top_states.plot(kind='bar',color='purple')

plt.title('The Top 20 States by Count')
plt.xticks(rotation=45)  # Rotate x-axis labels if needed


plt.show()

# %% [markdown]
# # **5. City**

# %%
top_cities = superstore_df['City'].value_counts().nlargest(20)


# Create the Bar Chart
plt.figure(figsize=(12,3))
top_cities.plot(kind='bar',color='Magenta')

plt.title('The Top 20 Cities by Count')
plt.xticks(rotation=45)  # Rotate x-axis labels if needed


plt.show()

# %% [markdown]
# # **6. Categories**

# %%
plt.figure(figsize=(15, 5))

# First subplot: Bar chart for top categories
top_categories = superstore_df['Category'].value_counts().nlargest(30)

plt.subplot(1, 3, 1)
top_categories.plot(kind='bar', color='Blue', width=0.5)
plt.title('Top Categories by Count')
plt.xticks(rotation=45)




# Second subplot: Boxplot of Profit by Categories
plt.subplot(1, 3, 2)
sns.boxplot(x='Category', y='Profit', data=superstore_df, palette='Blues')
plt.title('Boxplot of Profit by Categories')
plt.xlabel('Categories')
plt.ylabel('Profit')
plt.xticks(rotation=45)




# Third subplot: Pie chart for distribution of categories
category_counts = superstore_df['Category'].value_counts()

plt.subplot(1, 3, 3)
plt.pie(category_counts,
        labels=category_counts.index,
        autopct='%1.1f%%',
        startangle=140,
        colors=['lightblue', 'tomato', 'lightgreen'])
plt.title('Distribution of Categories (COUNT)')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle



plt.tight_layout()
plt.show()
print(category_counts)
# Out:
# Office Supplies    6012
# Furniture          2118
# Technology         1847
# Name: Category, dtype: int64

# %% [markdown]
# ### Inferences
#
# - Both the biggest outliers -6,000 and 8,000 are from the Technology Category.
#
# - Office Supplies Category has 60.3% of the share but the Technology Category has the Most Profit

# %% [markdown]
# # **7. Sub-Categories**

# %%
# value counts and nlargest
mostpopular_subcategories = superstore_df['Sub-Category'].value_counts().nlargest(30)



# Create the Bar Chart
plt.figure(figsize=(12,4))
mostpopular_subcategories.plot(kind='bar',color='purple', width = 0.5)


plt.title('The Top Sub-Categories by Count')
plt.xticks(rotation=45)  # Rotate x-axis labels if needed


plt.show()
print(mostpopular_subcategories)
# Out:
# Binders        1522
# Paper          1359
# Furnishings     956
# Phones          889
# Storage         846
# Art             795
# Accessories     775
# Chairs          615
# Appliances      466
# Labels          363
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %% [markdown]
# ###  **Those initial charts about the numerical and categorical data gave us some good insights**
#
#
# <br>
#
# ##  **Now let's dive deeper into the data**
#
#
#
# <br>
# <br>
# <br>
#
# # <span style="color:deepskyblue"> **PART 3: Numerical and Categorical data**

# %% [markdown]
# # <span style="color:deepskyblue"> **1.) Ship Mode (Profit, Sales, Quantity, Discount)**

# %%
plt.figure(figsize=(15, 5))


# First subplot: Boxplot of Profit by Ship Mode
plt.subplot(1, 4, 1)
sns.boxplot(x='Ship Mode', y='Profit', data=superstore_df, palette='Blues')
plt.title('Profit by Ship Mode')
plt.xlabel('Ship Mode')
plt.ylabel('Profit')
plt.xticks(rotation=45)



# Second subplot: Boxplot of Sales by Ship Mode
plt.subplot(1, 4, 2)
sns.boxplot(x='Ship Mode', y='Sales', data=superstore_df, palette='Blues')
plt.title('Sales by Ship Mode')
plt.xlabel('Ship Mode')
plt.ylabel('Sales')
plt.xticks(rotation=45)


# Third subplot: Boxplot of Quantity by Ship Mode
plt.subplot(1, 4, 3)
sns.boxplot(x='Ship Mode', y='Quantity', data=superstore_df, palette='Blues')
plt.title('Quantity by Ship Mode')
plt.xlabel('Ship Mode')
plt.ylabel('Quantity')
plt.xticks(rotation=45)


# Fourth subplot: Boxplot of Discount by Ship Mode
plt.subplot(1, 4, 4)
sns.boxplot(x='Ship Mode', y='Discount', data=superstore_df, palette='Blues')
plt.title('Discount by Ship Mode')
plt.xlabel('Ship Mode')
plt.ylabel('Discount')
plt.xticks(rotation=45)


plt.tight_layout()
plt.show()

# %% [markdown]
# ## Profit

# %%
# Bar Chart
shipmode_profit = superstore_df.groupby(['Ship Mode'])['Profit'].sum().nlargest(10)

plt.subplot(1, 2, 1)
shipmode_profit.plot(kind='bar', figsize=(15, 6), color = "green")

plt.title("Ship Mode and Profit")
plt.xlabel("Ship Mode")
plt.ylabel("Profit")
plt.xticks(rotation=45)





# Pie Chart
shipmode_profit = superstore_df.groupby(['Ship Mode'])['Profit'].sum().nlargest(10)

plt.subplot(1, 2, 2)
plt.pie(shipmode_profit,
        labels=shipmode_profit.index,
        autopct='%1.1f%%',
        startangle=60,
        colors=['lightblue', 'tomato', 'lightgreen', 'yellow'])
plt.title('Ship Mode and Profit')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle



plt.tight_layout()
plt.show()
print(shipmode_profit)
# Out:
# Ship Mode
# Standard Class    163969.2280
# Second Class       57446.6516
# First Class        48953.6561
# Same Day           15871.8869
# Name: Profit, dtype: float64

# %% [markdown]
# - Standard class Ship Mode is the Most Profitable. More than double the other classes.
#
# - Same Day Ship mode is the LEAST PROFITABLE.

# %% [markdown]
# ## Sales

# %%
shipmode_sales = superstore_df.groupby(['Ship Mode'])['Sales'].sum().nlargest(10)

# Create the chart
shipmode_sales.plot(kind='bar', figsize=(5, 4))

plt.title("Ship Mode and Sales")
plt.xlabel("Ship Mode")
plt.ylabel("Sales")
plt.xticks(rotation=45)


plt.show()
print(shipmode_sales)
# Out:
# Ship Mode
# Standard Class    1.357316e+06
# Second Class      4.591770e+05
# First Class       3.513805e+05
# Same Day          1.283217e+05
# Name: Sales, dtype: float64

# %% [markdown]
# ## Quantity

# %%
shipmode_quantity = superstore_df.groupby(['Ship Mode'])['Quantity'].sum().nlargest(10)

# Create the chart
shipmode_quantity.plot(kind='bar', figsize=(5, 4))

plt.title("Ship Mode and Quantity")
plt.xlabel("Ship Mode")
plt.ylabel("Quantity")
plt.xticks(rotation=45)


plt.show()
print(shipmode_quantity)
# Out:
# Ship Mode
# Standard Class    22756
# Second Class       7418
# First Class        5690
# Same Day           1956
# Name: Quantity, dtype: int64

# %% [markdown]
# ## Discount

# %%
shipmode_Discount = superstore_df.groupby(['Ship Mode'])['Discount'].sum().nlargest(10)

# Create the chart
shipmode_Discount.plot(kind='bar', figsize=(5, 4))

plt.title("Ship Mode and Discount")
plt.xlabel("Ship Mode")
plt.ylabel("Discount")
plt.xticks(rotation=45)


plt.show()
print(shipmode_Discount)
# Out:
# Ship Mode
# Standard Class    954.12
# Second Class      269.35
# First Class       252.97
# Same Day           82.75
# Name: Discount, dtype: float64

# %% [markdown]
# ### Inferences:
#
#
# - Standard class makes the MOST Profit. More than double the other classes.
#
#
# - Standard Class also has the Highest discount, Highest sales, and the Highest in Quantity.
#
# <br>
#
# - Same Day Ship mode is the LEAST PROFITABLE.

# %% [markdown]
# # <span style="color:deepskyblue"> **2.) Segment (Profit, Sales, Quantity, Discount)**

# %%
####### Profit




# Bar chart
Segment_profit = superstore_df.groupby(['Segment'])['Profit'].sum().nlargest(10)

plt.subplot(1, 2, 1)
Segment_profit.plot(kind='bar', figsize=(15, 5), color = "green")

plt.title("Segment and Profit")
plt.xlabel("Segment")
plt.ylabel("Profit")
plt.xticks(rotation=45)






# Pie Chart
Segment_profit = superstore_df.groupby(['Segment'])['Profit'].sum().nlargest(10)

plt.subplot(1, 2, 2)
plt.pie(Segment_profit,
        labels=Segment_profit.index,
        autopct='%1.1f%%',
        startangle=170,
        colors=['lightblue', 'tomato', 'lightgreen'])
plt.title('Segment and Profit')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle



plt.tight_layout()
plt.show()
print(Segment_profit)
# Out:
# Segment
# Consumer       134007.4413
# Corporate       91954.9798
# Home Office     60279.0015
# Name: Profit, dtype: float64

# %%
####### Sales

Segment_Sales = superstore_df.groupby(['Segment'])['Sales'].sum().nlargest(10)

# Create the chart
Segment_Sales.plot(kind='bar', figsize=(5, 4))

plt.title("Segment and Sales")
plt.xlabel("Segment")
plt.ylabel("Sales")
plt.xticks(rotation=45)


plt.show()
print(Segment_Sales)
# Out:
# Segment
# Consumer       1.160833e+06
# Corporate      7.060701e+05
# Home Office    4.292927e+05
# Name: Sales, dtype: float64

# %%
####### Quantity

Segment_Quantity = superstore_df.groupby(['Segment'])['Quantity'].sum().nlargest(10)

# Create the chart
Segment_Quantity.plot(kind='bar', figsize=(5, 4))

plt.title("Segment and Quantity")
plt.xlabel("Segment")
plt.ylabel("Quantity")
plt.xticks(rotation=45)



plt.show()
print(Segment_Quantity)
# Out:
# Segment
# Consumer       19497
# Corporate      11591
# Home Office     6732
# Name: Quantity, dtype: int64

# %%
####### Discount

Segment_Discount = superstore_df.groupby(['Segment'])['Discount'].sum().nlargest(10)

# Create the chart
Segment_Quantity.plot(kind='bar', figsize=(5, 4))

plt.title("Segment and Discount")
plt.xlabel("Segment")
plt.ylabel("Discount")
plt.xticks(rotation=45)


plt.show()
print(Segment_Discount)
# Out:
# Segment
# Consumer       820.51
# Corporate      476.85
# Home Office    261.83
# Name: Discount, dtype: float64

# %% [markdown]
# ### Inferences:
#
# - Consumer Segment is THE MOST PROFITABLE.
#
# - Consumer Segment also has the Highest discount, Highest sales, and the Highest in Quantity.
#
#
# <br>
#
# - Home Office Segment is THE LEAST PROFITABLE

# %%
superstore_df.describe(include="O")
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9977      9977           9977           9977        9977
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5955      5183           9977            914        1996
#
#        Region         Category Sub-Category
# count    9977             9977         9977
# unique      4                3           17
# top      West  Office Supplies      Binders
# freq     3193             6012         1522

# %% [markdown]
# ### We're skipping Country since there's only one value there: United States
#
# ### I decided not to drop it since I might be able to use it along with Postal code in a Tableau Dashboard
#
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# # <span style="color:deepskyblue"> **3.) City (Profit, Sales, Quantity, Discount)**

# %%
####### Profit

City_profit = superstore_df.groupby(['City'])['Profit'].sum().nlargest(20)

# Create the chart
City_profit.plot(kind='bar', figsize=(15, 4), color = "green")

plt.title("The Top 20 Most Profitable Cities")
plt.xlabel("City")
plt.ylabel("Profit")
plt.xticks(rotation=45)


plt.show()
print(City_profit)
# Out:
# City
# New York City    62013.8973
# Los Angeles      30431.4267
# Seattle          29121.6825
# San Francisco    17466.1186
# Detroit          13146.6935
# Lafayette        10018.3876
# Jackson           7581.6828
# Atlanta           6993.6629
# Minneapolis       6824.5846
# San Diego         6377.1960
# Springfield       6200.6974
# Columbus          5909.1601
# Newark            5793.7588
# Columbia          5606.1167
# Richmond          5567.2486
# Providence        5505.6569
# Henderson         4911.8609
# Arlington         4169.6969
# Lakewood          3234.0278
# Milwaukee         2793.0851
# Name: Profit, dtype: float64

# %%
####### Profit

City_profit_smallest = superstore_df.groupby(['City'])['Profit'].sum().nsmallest(20)

# Create the chart
City_profit_smallest.plot(kind='bar', figsize=(15, 4), color = "red")

plt.title("The Top 20 Least Profitable Cities")
plt.xlabel("City")
plt.ylabel("Profit")
plt.xticks(rotation=45)


plt.show()
print(City_profit_smallest)
# Out:
# City
# Philadelphia       -13843.2106
# Houston            -10175.1755
# San Antonio         -7299.0502
# Lancaster           -7239.0684
# Chicago             -6648.3318
# Burlington          -3622.8772
# Dallas              -2846.5257
# Phoenix             -2790.8832
# Aurora              -2691.7386
# Jacksonville        -2323.8350
# Memphis             -1479.0400
# Louisville          -1430.3129
# Medina              -1343.0446
# Round Rock          -1183.4313
# Knoxville           -1165.0755
# Miami               -1150.3704
# Rockford            -1149.5078
# Clarksville         -1055.3532
# Bethlehem           -1003.0958
# Colorado Springs     -956.6841
# Name: Profit, dtype: float64

# %% [markdown]
# ## Inference:
#
# ### The top 5 Most Profitable Cities:
#
# - New York City
# - Los Angeles
# - Seattle
# - San Francisco
# - Detroit
#
# <br>
# <br>
#
#
# ### The Top 5 Least Profitable Cities:
# - Philadelphia
# - Houston
# - San Antonio
# - Lancaster
# - Chicago
#
#
#
#
# <br><br>
#
#
# Let's Inspect the City of Philadelphia more to find out why it's the least profitable City.

# %%
####### Sales

City_Sales = superstore_df.groupby(['City'])['Sales'].sum().nlargest(20)

# Create the chart
City_Sales.plot(kind='bar', figsize=(15, 4), color = "blue")

plt.title("City and Sales")
plt.xlabel("City")
plt.ylabel("Sales")
plt.xticks(rotation=45)


plt.show()
print(City_Sales)
# Out:
# City
# New York City    256319.0410
# Los Angeles      175831.9010
# Seattle          119460.2820
# San Francisco    112577.1720
# Philadelphia     109061.4610
# Houston           64441.2564
# Chicago           48535.9770
# San Diego         47521.0290
# Jacksonville      44713.1830
# Springfield       43054.3420
# Detroit           42056.9740
# Columbus          38424.8710
# Newark            28576.1190
# Columbia          25283.3240
# Lafayette         25036.2000
# Jackson           24963.8580
# San Antonio       21843.5280
# Burlington        21668.0820
# Arlington         20214.5320
# Dallas            20131.9322
# Name: Sales, dtype: float64

# %%
####### Quantity


City_Quantity = superstore_df.groupby(['City'])['Quantity'].sum().nlargest(20)

# Create the chart
City_Quantity.plot(kind='bar', figsize=(15, 4), color = "blue")

plt.title("City and Quantity")
plt.xlabel("City")
plt.ylabel("Quantity")
plt.xticks(rotation=45)


plt.show()
print(City_Quantity)
# Out:
# City
# New York City    3413
# Los Angeles      2876
# Philadelphia     1978
# San Francisco    1920
# Seattle          1578
# Houston          1460
# Chicago          1129
# Columbus          834
# San Diego         670
# Springfield       649
# Dallas            555
# Detroit           438
# Jacksonville      429
# Newark            362
# Richmond          336
# Jackson           318
# Columbia          316
# Arlington         259
# Aurora            258
# Long Beach        256
# Name: Quantity, dtype: int64

# %%
####### Discount


City_Discount = superstore_df.groupby(['City'])['Discount'].sum().nlargest(20)

# Create the chart
City_Discount.plot(kind='bar', figsize=(15, 4), color = "blue")

plt.title("City and Discount")
plt.xlabel("City")
plt.ylabel("Discount")
plt.xticks(rotation=45)


plt.show()
print(City_Discount)
# Out:
# City
# Philadelphia     175.30
# Houston          142.74
# Chicago          119.70
# Dallas            56.30
# Los Angeles       55.50
# New York City     51.40
# Columbus          38.20
# Jacksonville      35.85
# San Francisco     34.00
# Seattle           27.80
# Aurora            24.00
# Springfield       23.20
# San Antonio       22.60
# Phoenix           22.30
# Miami             18.65
# Charlotte         15.30
# Lancaster         14.50
# San Diego         13.60
# Austin            13.40
# Cleveland         12.80
# Name: Discount, dtype: float64

# %% [markdown]
# ### Inferences:
#
#
# - New York City is the Most Profitable City. It also has the highest Sales and Quantity
#
#
# - The City of Philadelphia is the Least Profitable city, It also has the Highest Discount

# %% [markdown]
# # <span style="color:deepskyblue"> **4.) State (Profit, Sales, Quantity, Discount)**

# %%
####### Profit

State_profit = superstore_df.groupby(['State'])['Profit'].sum().nlargest(20)


# Create the chart
State_profit.plot(kind='bar', figsize=(15, 4), color = "green")

plt.title("The Top 20 Most Profitable States")
plt.xlabel("State")
plt.ylabel("Profit")
plt.xticks(rotation=45)



plt.show()
print(State_profit)
# Out:
# State
# California       76330.7891
# New York         74015.4622
# Washington       33368.2375
# Michigan         24428.0903
# Virginia         18597.9504
# Indiana          18382.9363
# Georgia          16250.0433
# Kentucky         11199.6966
# Minnesota        10823.1874
# Delaware          9977.3748
# New Jersey        9772.9138
# Wisconsin         8401.8004
# Rhode Island      7285.6293
# Maryland          7031.1788
# Massachusetts     6785.5016
# Missouri          6436.2105
# Alabama           5786.8253
# Oklahoma          4853.9560
# Arkansas          4008.6871
# Connecticut       3511.4918
# Name: Profit, dtype: float64

# %%
####### Profit

State_profit_smallest = superstore_df.groupby(['State'])['Profit'].sum().nsmallest(20)


# IF Statement with a For loop
COLORS = ['green' if profit > 0 else 'red' for profit in State_profit_smallest]



# Create the chart
State_profit_smallest.plot(kind='bar', figsize=(15, 4), color = COLORS)

plt.title("The Top 20 Least Profitable States")
plt.xlabel("State")
plt.ylabel("Profit")
plt.xticks(rotation=45)



plt.show()
print(State_profit_smallest)
# Out:
# State
# Texas                  -25750.9833
# Ohio                   -16959.3178
# Pennsylvania           -15565.4035
# Illinois               -12601.6500
# North Carolina          -7490.9122
# Colorado                -6527.8579
# Tennessee               -5341.6936
# Arizona                 -3427.9246
# Florida                 -3399.3017
# Oregon                  -1194.0993
# Wyoming                   100.1960
# West Virginia             185.9216
# North Dakota              230.1497
# South Dakota              394.8283
# Maine                     454.4862
# Idaho                     826.7231
# Kansas                    836.4435
# District of Columbia     1059.5893
# New Mexico               1157.1161
# Iowa                     1183.8119
# Name: Profit, dtype: float64

# %% [markdown]
# ## Inference:
#
# ### The top 5 Most Profitable States:
#
# - California
# - New York
# - Washington
# - Michigan
# - Virginia
#
# <br>
# <br>
#
#
# ### The Top 5 Least Profitable States:
#
# - Texas
# - Ohio
# - Pennsylvania
# - Illinois
# - North Carolina
#
#
# <br>
#
#
# Let's Inspect the State of Texas more to find out why it has it's the least profitable State.

# %%
####### Sales

State_Sales = superstore_df.groupby(['State'])['Sales'].sum().nlargest(20)


# Create the chart
State_Sales.plot(kind='bar', figsize=(15, 4), color = "blue")

plt.title("State and Sales")
plt.xlabel("State")
plt.ylabel("Sales")
plt.xticks(rotation=45)



plt.show()
print(State_Sales)
# Out:
# State
# California        457576.2715
# New York          310827.1510
# Texas             170124.5418
# Washington        138560.8100
# Pennsylvania      116496.3620
# Florida            89473.7080
# Illinois           80162.5370
# Ohio               77976.7640
# Michigan           75879.6440
# Virginia           70636.7200
# North Carolina     55603.1640
# Indiana            53555.3600
# Georgia            49095.8400
# Kentucky           36591.7500
# New Jersey         35764.3120
# Arizona            35282.0010
# Wisconsin          32114.6100
# Colorado           32108.1180
# Tennessee          30661.8730
# Minnesota          29863.1500
# Name: Sales, dtype: float64

# %%
####### Quantity

State_Quantity = superstore_df.groupby(['State'])['Quantity'].sum().nlargest(20)


# Create the chart
State_Quantity.plot(kind='bar', figsize=(15, 4), color = "blue")

plt.title("State and Quantity")
plt.xlabel("State")
plt.ylabel("Quantity")
plt.xticks(rotation=45)



plt.show()
print(State_Quantity)
# Out:
# State
# California        7649
# New York          4220
# Texas             3718
# Pennsylvania      2150
# Washington        1871
# Illinois          1842
# Ohio              1757
# Florida           1379
# North Carolina     983
# Michigan           943
# Virginia           893
# Arizona            862
# Georgia            705
# Colorado           693
# Tennessee          681
# Indiana            578
# Kentucky           523
# Oregon             497
# Massachusetts      491
# Wisconsin          463
# Name: Quantity, dtype: int64

# %%
####### Discount

State_Discount = superstore_df.groupby(['State'])['Discount'].sum().nlargest(20)


# Create the chart
State_Discount.plot(kind='bar', figsize=(15, 4), color = "blue")

plt.title("State and Discount")
plt.xlabel("State")
plt.ylabel("Discount")
plt.xticks(rotation=45)



plt.show()
print(State_Discount)
# Out:
# State
# Texas             364.24
# Pennsylvania      192.70
# Illinois          191.10
# Ohio              152.10
# California        145.60
# Florida           114.65
# North Carolina     70.60
# Arizona            68.00
# New York           62.40
# Colorado           57.60
# Tennessee          53.30
# Oregon             35.60
# Washington         32.40
# Utah                3.20
# Nevada              2.40
# New Mexico          2.20
# Massachusetts       2.10
# Idaho               1.80
# Michigan            1.80
# Rhode Island        1.20
# Name: Discount, dtype: float64

# %% [markdown]
# ### Inferences:
#
# - California is the Most Profitable State. It also has the Highest Sales and Highest in Quantity
#
#
# - <span style="color:deepskyblue"> **Texas also has the 3rd Highest in Sales and Quantity, yet it's still the Least Profitable.**
#
# - Texas is the Least Profitable State. It also has the Highest Discount
#
#
#     This is the same for the other columns. Going back to our Scatter Plot of Discount and Profit, we can see they are Negatively correlated.

# %% [markdown]
# # <span style="color:deepskyblue"> **5.) Region (Profit, Sales, Quantity, Discount)**

# %%
####### Profit


# Bar Chart
Region_profit = superstore_df.groupby(['Region'])['Profit'].sum().nlargest(20)

plt.subplot(1, 2, 1)
Region_profit.plot(kind='bar', figsize=(15, 5), color = "green")

plt.title("Region and Profit")
plt.xlabel("Region")
plt.ylabel("Profit")
plt.xticks(rotation=45)





# Pie Chart
Region_profit = superstore_df.groupby(['Region'])['Profit'].sum().nlargest(10)

plt.subplot(1, 2, 2)
plt.pie(Region_profit,
        labels=Region_profit.index,
        autopct='%1.1f%%',
        startangle=140,
        colors=['lightblue', 'tomato', 'lightgreen', 'yellow'])
plt.title('Region and Profit')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle



plt.tight_layout()
plt.show()
print(Region_profit)
# Out:
# Region
# West       108329.8079
# East        91506.3092
# South       46749.4303
# Central     39655.8752
# Name: Profit, dtype: float64

# %% [markdown]
# ### Inference:
#
# - West is the Most Profitable Region
#
# - Central is the Least Profitable Region

# %%
####### Sales

Region_Sales = superstore_df.groupby(['Region'])['Sales'].sum().nlargest(20)

# Create the chart
Region_Sales.plot(kind='bar', figsize=(5, 4), color = "blue")

plt.title("Region and Sales")
plt.xlabel("Region")
plt.ylabel("Sales")
plt.xticks(rotation=45)


plt.show()
print(Region_Sales)
# Out:
# Region
# West       725255.6365
# East       678435.1960
# Central    500782.8528
# South      391721.9050
# Name: Sales, dtype: float64

# %%
####### Quantity

Region_Quantity = superstore_df.groupby(['Region'])['Quantity'].sum().nlargest(20)

# Create the chart
Region_Quantity.plot(kind='bar', figsize=(5, 4), color = "blue")

plt.title("Region and Quantity")
plt.xlabel("Region")
plt.ylabel("Quantity")
plt.xticks(rotation=45)


plt.show()
print(Region_Quantity)
# Out:
# Region
# West       12234
# East       10609
# Central     8768
# South       6209
# Name: Quantity, dtype: int64

# %%
####### Discount

Region_Discount = superstore_df.groupby(['Region'])['Discount'].sum().nlargest(20)

# Create the chart
Region_Discount.plot(kind='bar', figsize=(5, 4), color = "blue")

plt.title("Region and Discount")
plt.xlabel("Region")
plt.ylabel("Discount")
plt.xticks(rotation=45)


plt.show()
print(Region_Discount)
# Out:
# Region
# Central    557.14
# East       413.50
# West       350.00
# South      238.55
# Name: Discount, dtype: float64

# %% [markdown]
# ### Inferences
#
# - West Region is the Most Profitable, It also has the Highest Sales and Most Quantity
#
#
# - Central Region is the Least Profitable, It also has the Highest Discount
#
#
# - We could reduce the discounts on Central Region since it's not making a lot of Profit

# %% [markdown]
# # <span style="color:deepskyblue"> **6.) Category (Profit, Sales, Quantity, Discount)**

# %%
####### Profit



# Bar Chart
Category_profit = superstore_df.groupby(['Category'])['Profit'].sum().nlargest(20)

plt.subplot(1, 2, 1)
Category_profit.plot(kind='bar', figsize=(15, 5), color = "green")

plt.title("Category and Profit")
plt.xlabel("Category")
plt.ylabel("Profit")
plt.xticks(rotation=45)






# Pie Chart
Category_profit = superstore_df.groupby(['Category'])['Profit'].sum().nlargest(10)

plt.subplot(1, 2, 2)
plt.pie(Category_profit,
        labels=Category_profit.index,
        autopct='%1.1f%%',
        startangle=140,
        colors=['lightblue', 'tomato', 'lightgreen'])
plt.title('Category and Profit')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle



plt.tight_layout()
plt.show()
print(Category_profit)
# Out:
# Category
# Technology         145454.9481
# Office Supplies    122364.6608
# Furniture           18421.8137
# Name: Profit, dtype: float64

# %%
####### Sales

Category_Sales = superstore_df.groupby(['Category'])['Sales'].sum().nlargest(20)

# Create the chart
Category_Sales.plot(kind='bar', figsize=(5, 4), color = "blue")

plt.title("Category and Sales")
plt.xlabel("Category")
plt.ylabel("Sales")
plt.xticks(rotation=45)


plt.show()
print(Category_Sales)
# Out:
# Category
# Technology         836154.0330
# Furniture          741306.3133
# Office Supplies    718735.2440
# Name: Sales, dtype: float64

# %%
####### Quantity

Category_Quantity = superstore_df.groupby(['Category'])['Quantity'].sum().nlargest(20)

# Create the chart
Category_Quantity.plot(kind='bar', figsize=(5, 4), color = "blue")

plt.title("Category and Quantity")
plt.xlabel("Category")
plt.ylabel("Quantity")
plt.xticks(rotation=45)


plt.show()
print(Category_Quantity)
# Out:
# Category
# Office Supplies    22861
# Furniture           8020
# Technology          6939
# Name: Quantity, dtype: int64

# %%
####### Discount

Category_Discount = superstore_df.groupby(['Category'])['Discount'].sum().nlargest(20)

# Create the chart
Category_Discount.plot(kind='bar', figsize=(5, 4), color = "blue")

plt.title("Category and Discount")
plt.xlabel("Category")
plt.ylabel("Discount")
plt.xticks(rotation=45)


plt.show()
print(Category_Discount)
# Out:
# Category
# Office Supplies    946.20
# Furniture          368.59
# Technology         244.40
# Name: Discount, dtype: float64

# %% [markdown]
# ### Inference
#
# - **Technology is the Most Profitable Category, followed closely by Office Supplies**
#
#     **Technology Category also has the Highest Sales**
#
# <br>
#
# - **Furniture is the Least Profitable Category,**
#
#
# - <span style="color:deepskyblue"> **We make a lot of Sales on the Furniture Category but it's still the Least Profitable. (only 6.4% of the Total Profit)**
#
#
# <br><br>
#
#
#
# - **Office Supplies Category has the Highest Discount, yet this Category still makes good Profits.**
#
#
# - **Office Supplies Category also has the Highest Quantity, almost triple the amount the other categories have**
#
#
#
# <br><br><br>
#
# - The most profitable category is **7.88 times** more profitable than the least profitable category.
#
#     This means that the most profitable category generates **$7.88** of profit for every **$1** of profit generated by the least profitable category.

# %% [markdown]
# # <span style="color:deepskyblue"> **7.) Sub-Category (Profit, Sales, Quantity, Discount)**

# %%
####### Profit

SubCategory_profit = superstore_df.groupby(['Sub-Category'])['Profit'].sum().nlargest(20)


# IF Statement with a For loop
COLORS = ['green' if profit > 0 else 'red' for profit in SubCategory_profit]


# Create the chart
SubCategory_profit.plot(kind='bar', figsize=(15, 4), color = COLORS)

plt.title("Sub-Category and Profit")
plt.xlabel("Sub-Category")
plt.ylabel("Profit")
plt.xticks(rotation=45)


plt.show()
print(SubCategory_profit)
# Out:
# Sub-Category
# Copiers        55617.8249
# Phones         44515.7306
# Accessories    41936.6357
# Paper          33944.2395
# Binders        30228.0003
# Chairs         26567.1278
# Storage        21278.8264
# Appliances     18138.0054
# Furnishings    13052.7230
# Envelopes       6964.1767
# Art             6524.6118
# Labels          5526.3820
# Machines        3384.7569
# Fasteners        949.5182
# Supplies       -1189.0995
# Bookcases      -3472.5560
# Tables        -17725.4811
# Name: Profit, dtype: float64

# %% [markdown]
# ### Inferences
#
# - Copiers is the Most Profitable product or Sub-Category (55,617.82)
#
# - Tables is the Least Profitable product or Sub-Category (-17,725.48)
#
# <br><br>

# %%
####### Sales

SubCategory_Sales = superstore_df.groupby(['Sub-Category'])['Sales'].sum().nlargest(20)

# Create the chart
SubCategory_Sales.plot(kind='bar', figsize=(15, 4), color = "blue")

plt.title("Sub-Category and Sales")
plt.xlabel("Sub-Category")
plt.ylabel("Sales")
plt.xticks(rotation=45)


plt.show()
print(SubCategory_Sales)
# Out:
# Sub-Category
# Phones         330007.0540
# Chairs         327777.7610
# Storage        223843.6080
# Tables         206965.5320
# Binders        203409.1690
# Machines       189238.6310
# Accessories    167380.3180
# Copiers        149528.0300
# Bookcases      114879.9963
# Appliances     107532.1610
# Furnishings     91683.0240
# Paper           78224.1420
# Supplies        46673.5380
# Art             27107.0320
# Envelopes       16476.4020
# Labels          12444.9120
# Fasteners        3024.2800
# Name: Sales, dtype: float64

# %% [markdown]
# ### Inferences:
#
# - <span style="color:deepskyblue"> **Tables is actually the 4th best-selling product or Sub-category, yet it's the Least Profitable**
#
# <br>
# <br>

# %%
####### Quantity

SubCategory_Quantity = superstore_df.groupby(['Sub-Category'])['Quantity'].sum().nlargest(20)

# Create the chart
SubCategory_Quantity.plot(kind='bar', figsize=(15, 4), color = "blue")

plt.title("Sub-Category and Quantity")
plt.xlabel("Sub-Category")
plt.ylabel("Quantity")
plt.xticks(rotation=45)


plt.show()
print(SubCategory_Quantity)
# Out:
# Sub-Category
# Binders        5971
# Paper          5144
# Furnishings    3560
# Phones         3289
# Storage        3158
# Art            2996
# Accessories    2976
# Chairs         2351
# Appliances     1729
# Labels         1396
# Tables         1241
# Fasteners       914
# Envelopes       906
# Bookcases       868
# Supplies        647
# Machines        440
# Copiers         234
# Name: Quantity, dtype: int64

# %%
####### Discount

SubCategory_Discount = superstore_df.groupby(['Sub-Category'])['Discount'].sum().nlargest(20)

# Create the chart
SubCategory_Discount.plot(kind='bar', figsize=(15, 4), color = "blue")

plt.title("Sub-Category and Discount")
plt.xlabel("Sub-Category")
plt.ylabel("Discount")
plt.xticks(rotation=45)


plt.show()
print(SubCategory_Discount)
# Out:
# Sub-Category
# Binders        566.20
# Phones         137.40
# Furnishings    132.40
# Chairs         104.70
# Paper          101.80
# Tables          83.35
# Appliances      77.60
# Storage         63.20
# Accessories     60.80
# Art             59.60
# Bookcases       48.14
# Machines        35.20
# Labels          25.00
# Envelopes       20.40
# Fasteners       17.80
# Supplies        14.60
# Copiers         11.00
# Name: Discount, dtype: float64

# %% [markdown]
# - Binders is the product or Sub-Category with the highest Discount
#
#
# - Tables is the product or Sub-Category with the 6th highest Discount (Worst performing Sub-category in Profit)

# %% [markdown]
# ## <span style="color:deepskyblue"> **Additional analysis using cross tab on our Categorical data**

# %% [markdown]
# ## Stacked Bar Chart - Ship Mode and Segment

# %%
cross_tab = pd.crosstab(superstore_df['Segment'], superstore_df['Ship Mode'])


plt.figure(figsize=(10, 6))
cross_tab.plot(kind='bar', stacked=True, colormap='viridis')


plt.title('Stacked Bar Chart of Ship Mode by Segment')
plt.xlabel('Segment')
plt.ylabel('Count')
plt.xticks(rotation=0)  
plt.legend(title='Ship Mode', loc='upper right')


plt.show()
print(cross_tab)
# Out:
# Ship Mode    First Class  Same Day  Second Class  Standard Class
# Segment
# Consumer             768       317          1019            3079
# Corporate            485       114           608            1808
# Home Office          284       111           316            1068

# %% [markdown]
# In this code:
#
# 1. We use `pd.crosstab` from the pandas library to create a contingency table that shows the count of each combination of "Segment" and "Ship Mode."
#
# 2. We create a stacked bar chart by setting `stacked=True` when calling the `plot()` method on the `cross_tab` DataFrame.

# %% [markdown]
# ## Heatmap - Region vs Category

# %%
cross_tab = pd.crosstab(superstore_df['Region'], superstore_df['Category'])



sns.heatmap(cross_tab, annot=True, fmt='d', cmap='YlGnBu')


plt.title('Heatmap of Region vs. Category')
plt.xlabel('Category')
plt.ylabel('Region')



plt.show()
print(cross_tab)
# Out:
# Category  Furniture  Office Supplies  Technology
# Region
# Central         480             1419         420
# East            600             1710         535
# South           332              995         293
# West            706             1888         599

# %% [markdown]
# In this code:
#
# 1. We first use `pd.crosstab` to create a cross-tabulation or contingency table of "Region" and "Category." This table shows the count of each combination of region and category.
#
# 2. We create a heatmap using Seaborn's `heatmap()` function. We provide the cross-tabulation as the data, set `annot=True` to display the cell values, use `fmt='d'` to format cell values as integers, and choose a colormap (`cmap`) for the heatmap.

# %% [markdown]
# <br>
#
# ### **Going back to our original problem:**
#
#
# ### **What Business problems can I derive by exploring the data?**
#
#
# ### <span style="color:deepskyblue"> **As a business manager, try to find out the weak areas where I can work to make profit.**
#
#
# ### **During our Exploratory Data Analysis, we were able to find out our strong and weak areas**
#
#
#
#
# <br><br><br><br><br><br>
#
#
#
# # <span style="color:deepskyblue"> **FINDINGS / KEY INSIGHTS:**

# %% [markdown]
# ### <span style="color:deepskyblue"> **This will be the color of our VALUABLE INSIGHTS**
#
# ### <span style="color:red"> **This will be the color of our WEAK AREAS that need attention.**
#
# <br><br><br>
#
#
#
#
# # **1. SHIP MODE**
#
# - Standard Class makes the MOST Profit. More than double the other classes.
#
# - Standard Class also has the Highest discount, Highest sales, and the Highest in Quantity.
#
#
# - <span style="color:red"> **Same Day Ship mode is the LEAST PROFITABLE.**
#
#
# <br><br><br>
#
#
#
#
#
#
#
#
#
# # **2. SEGMENT**
#
# - Consumer Segment is THE MOST PROFITABLE.
#
# - Consumer Segment also has the Highest discount, Highest sales, and the Highest in Quantity.
#
#
# <br>
#
# - <span style="color:red"> **Home Office Segment is THE LEAST PROFITABLE**
#
#
#
# <br><br><br>
#
#
#
#
#
#
#
#
# # **3. CITY**
#
# ### The top 5 Most Profitable Cities:
#
# - New York City
# - Los Angeles
# - Seattle
# - San Francisco
# - Detroit
#
# <br>
# <br>
#
#
# ### The Top 5 Least Profitable Cities:
# - <span style="color:red"> **Philadelphia**
# - <span style="color:red"> **Houston**
# - <span style="color:red"> **San Antonio**
# - <span style="color:red"> **Lancaster**
# - <span style="color:red"> **Chicago**
#
# <br><br>
#
# - New York City is the Most Profitable City. It also has the Highest Sales and Highest in Quantity.
#
#
# - <span style="color:red"> **The City of Philadelphia is the Least Profitable city, It also has the Highest Discount.**
#
#
# <br><br><br>
#
#
#
#
#
#
#
#
#
#
#
# # **4. STATE**
#
# ### The top 5 Most Profitable States:
#
# - California
# - New York
# - Washington
# - Michigan
# - Virginia
#
#
# ### The Top 5 Least Profitable States:
#
# - <span style="color:red"> **Texas**
# - <span style="color:red"> **Ohio**
# - <span style="color:red"> **Pennsylvania**
# - <span style="color:red"> **Illinois**
# - <span style="color:red"> **North Carolina**
#
#
# <br><br>
#
#
# - California is the Most Profitable State. It also has the Highest Sales and Highest in Quantity
#
#
# - <span style="color:red"> **Texas is the Least Profitable State. It also has the Highest Discount**
#
#
# - <span style="color:red"> **Texas also has the 3rd Highest in Sales and Quantity, yet it's still the Least Profitable.**
#
# <br><br>
#
#
# ### <span style="color:deepskyblue"> **This is the same for the City and other previous columns, those with the Highest Discount tend to have lesser profits.**
#
#
# ### <span style="color:deepskyblue"> **Going back to our Scatter Plot of Discount and Profit, we can see that Discount and Profit are Negatively correlated.**
#
#
# ### <span style="color:deepskyblue"> **It appears that we are not making Profits if the Discount is too high.**
#
#
# <br><br><br>

# %% [markdown]
# # **5. REGION**
#
#
# - West Region is the Most Profitable, It also has the Most Sales and Most Quantity
#
#
# - <span style="color:red"> **Central Region is the Least Profitable, It also has the Highest Discount**
#
#     We could reduce the discounts on Central Region since it's not making a lot of Profit
#
#
# <br><br><br>
#
#
#
#
#
#
#
#
# # **6. CATEGORY**
#
#
# - **Technology is the Most Profitable Category, followed closely by Office Supplies**
#
#     **Technology Category also has the Highest Sales**
#
# <br>
#
# -  <span style="color:red"> **Furniture is the Least Profitable Category**
#
#
# - <span style="color:red"> **We make a lot of Sales in the Furniture Category but it's still the Least Profitable. (only 6.4% of the Total Profit)**
#
#
# <br>
#
#
#
# - <span style="color:deepskyblue"> **Office Supplies Category has the Highest Discount, yet this Category still makes good Profits.**
#
#
# - **Office Supplies Category also has the Highest Quantity, almost triple the amount the other categories have**
#
#
#
#
# <br><br><br>
#
#
#
#
#
#
#
#
# # **7. SUB-CATEGORY**
#
#
# - Copiers is the Most Profitable product or Sub-Category (55,617.82)
#
#
# - <span style="color:red"> **Tables is the Least Profitable product or Sub-Category (-17,725.48)**
#
# <br>
#
# - <span style="color:deepskyblue"> **Tables is actually the 4th best-selling product or Sub-category, yet it's the Least Profitable**
#
# - We could just drop the Tables product or Sub-Category since we aren’t making any profits, we’re just losing a lot of money despite this product making a lot of Sales.
#
# <br>
#
# - Binders is the product or Sub-Category with the highest Discount
#
# - <span style="color:red"> **Tables is the product or Sub-Category with the 6th highest Discount (Worst performing Sub-category in Profit)**
#
#
#
# <br><br><br><br><br><br><br><br><br>

# %% [markdown]
# # <span style="color:deepskyblue"> **CONCLUSION:**
#
# <br>
#
#
# # **1. Ship Mode**
#
# The profit of the ship modes follows a decreasing order from Standard Class, to Second Class, to First Class to Same Day.
#
# <span style="color:deepskyblue"> **This suggests that there might be a trade-off between the speed and the cost of shipping,**
#
# <span style="color:deepskyblue"> **and that customers might prefer lower shipping costs over faster delivery times.**
#
# <span style="color:deepskyblue"> **(Customers would rather wait than spend more money).**
#
#
#
#
# <br><br><br>
#
#
# # **2. Segment**
#
# <span style="color:deepskyblue"> **The company should focus more on the consumer segment, as it has the most potential for growth and profitability.
# The company can increase its marketing efforts, offer discounts or incentives, and expand its product range for this segment. (Double down on our Strengths)**
#
#
# The company should maintain its performance in the corporate segment, as it has a stable and consistent demand and profitability. The company can strengthen its relationships with existing clients, provide quality service and support, and seek new opportunities for collaboration or partnership with them.
#
#
# <span style="color:deepskyblue"> **The company should also improve its performance in the home office segment, as it has the least potential for growth and profitability. The company can conduct market research, identify the needs and preferences of this segment, and offer customized or tailored solutions for them.**
#
# <br><br><br>
#
#
#
# # **3. City**
#
# New York City is the most profitable city.
#
# <span style="color:deepskyblue"> **New York City is a significant market for the Superstore, and strategies that have worked there could potentially be applied to other locations. (Double down on our Strengths)**
#
#
# <span style="color:deepskyblue"> **Philadelphia is the least profitable city, and it also has the highest discount. This raises questions about the effectiveness of the current pricing and discount strategies in Philadelphia. Further analysis is needed to understand why this city is underperforming compared to others.**
#
# <br>
#
# Market Potential: Cities like Los Angeles and Seattle also have very high profits.
#
# This suggests that these markets have significant potential for growth. Stakeholders could consider allocating more resources and marketing efforts to these cities to capitalize on their profitability.
#
# <br><br><br>
#
#
#
#
# # **4. State**
#
# California is the Most Profitable State,  It also has the Highest Sales and Highest in Quantity which may have helped.
#
#
# <span style="color:deepskyblue"> **Texas is the least profitable State, and it also has the highest discount.**
#
#
# <span style="color:deepskyblue"> **Texas also has the 3rd Highest in Sales and Quantity, yet it's still the Least Profitable.**
#
#
# <span style="color:deepskyblue"> **This suggests that offering high discounts might not necessarily translate to higher profits, and it's worth exploring whether adjusting the discount strategy in Texas could improve profitability.**
#
#
#
#
# <br><br><br>
#
#
# # **5. Region**
#
# West is the Most Profitable Region, It also has the Highest Sales and the Highest in Quantity
#
# <span style="color:deepskyblue"> **The East region follows closely behind the West in terms of profitability.**
#
#
# <span style="color:deepskyblue"> **It's clear that both the West and East regions significantly contribute to the company's overall profitability.**
#
#
# Central Region is the Least Profitable, It also has the Highest Discount
#
#
# <span style="color:deepskyblue"> **We could reduce the discounts on Central Region since it's not making a lot of Profit.**
#
# <span style="color:deepskyblue"> **That's the same problem with the previous columns/categorical data.**
#
#
#
# <br><br><br>
#
#
#
#
# # **6. Category**
#
# <span style="color:deepskyblue"> **Technology and Office Supplies are the most profitable categories**
#
# <span style="color:deepskyblue"> **This suggests that these two categories are the primary drivers of profitability for the Superstore.**
#
#
# <br>
#
# <span style="color:deepskyblue"> **The most profitable category is 7.88 times more profitable than the least profitable category.**
#
# <span style="color:deepskyblue"> **This shows that the most profitable category is the dominant source of profit and has a high impact on the overall performance of the business.**
#
#
#
# <br><br><br>
#
#
# # **7. Sub-Category**
#
# Copiers is the Most Profitable product or Sub-Category (55,617.82)
#
# Tables is the Least Profitable product or Sub-Category (-17,725.48)
#
# <br>
#
# <span style="color:deepskyblue"> **Binders is the product or sub-category with the highest discount. This could be impacting its profitability.**
#
# <br>
#
# <span style="color:deepskyblue"> **We could just drop the Tables product or Sub-Category since we aren’t making any profits**
#
# <span style="color:deepskyblue"> **We’re just losing a lot of money despite Tables being the 4th best-selling Sub-Category.**
#
# <br><br><br>

# %% [markdown]
# ## <span style="color:deepskyblue"> **Export to CSV**
#
#
# To turn it into a Tableau Dashboard

# %%
superstore_df.to_csv('SampleSuperstore_for_dashboard.csv', index = False)

print("Data successfully exported to CSV file")
# Out:
# Data successfully exported to CSV file

# %%
for_dashboard_df = pd.read_csv('SampleSuperstore_for_dashboard.csv')


for_dashboard_df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9972    Second Class   Consumer  United States            Miami     Florida
# 9973  Standard Class   Consumer  United States       Costa Mesa  California
# 9974  Standard Class   Consumer  United States       Costa Mesa  California
# 9975  Standard Class   Consumer  United States       Costa Mesa  California
# 9976    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
for_dashboard_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9977 entries, 0 to 9976
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9977 non-null   object
#  1   Segment       9977 non-null   object
#  2   Country       9977 non-null   object
#  3   City          9977 non-null   object
#  4   State         9977 non-null   object
#  5   Postal Code   9977 non-null   int64
#  6   Region        9977 non-null   object
#  7   Category      9977 non-null   object
#  8   Sub-Category  9977 non-null   object
#  9   Sales         9977 non-null   float64
#  10  Quantity      9977 non-null   int64
#  11  Discount      9977 non-null   float64
#  12  Profit        9977 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1013.4+ KB

# %% [markdown]
# # <span style="color:deepskyblue"> **THE END**
